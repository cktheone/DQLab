# %% [markdown]
# import data

# %%
import pandas as pd

data = pd.read_excel('data_source/Datsar_Daop6.xlsx', sheet_name='Kereta_SLO')
data.head()
# Out:
#       No       Nomor      KAI               Area Depo Nomor Lama  \
# 0    NaN         128      NaN                NaN  NaN        NaN
# 1   10.0   B 0 07 16   B00716  Daop 6 Yogyakarta  SLO    B 07516
# 2   11.0   B 0 07 17   B00717  Daop 6 Yogyakarta  SLO    B 07517
# 3  158.0  K1 0 09 01  K100901  Daop 6 Yogyakarta  SLO   K1 09501
# 4  159.0  K1 0 09 02  K100902  Daop 6 Yogyakarta  SLO   K1 09502
#
#    Usia (Tahun)           UMUR   Kategori Jenis       JENIS 2 JENIS BARU  \
# 0           NaN            NaN        NaN   NaN           NaN        NaN
# 1          14.0  11 - 20 Tahun     BAGASI     B      B BAGASI          B
# 2          14.0  11 - 20 Tahun     BAGASI     B      B BAGASI          B
# 3          12.0  11 - 20 Tahun  EKSEKUTIF    K1  K1 EKSEKUTIF         K1
# 4          12.0  11 - 20 Tahun  EKSEKUTIF    K1  K1 EKSEKUTIF         K1
#
#   Mulai Dinas   TAHUN  No. Equipment KETERANGAN SERTIFIKAT  \
# 0         NaN     NaN            NaN                    63
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   No                     128 non-null    float64
#  1   Nomor                  129 non-null    object
#  2   KAI                    128 non-null    object
#  3   Area                   128 non-null    object
#  4   Depo                   128 non-null    object
#  5   Nomor Lama             67 non-null     object
#  6   Usia (Tahun)           128 non-null    float64
#  7   UMUR                   128 non-null    object
#  8   Kategori               128 non-null    object
#  9   Jenis                  128 non-null    object
#  10  JENIS 2                128 non-null    object
#  11  JENIS BARU             128 non-null    object
#  12  Mulai Dinas            128 non-null    object
#  13  TAHUN                  128 non-null    float64
# ...

# %% [markdown]
# seleksi data berdasarakan kolom tertentu

# %%
data2 = data[['Nomor','Usia (Tahun)', 'Kategori', 'KETERANGAN SERTIFIKAT', 'KETERANGAN RAMPCHECK']]

# %%
data2.head()
# Out:
#         Nomor  Usia (Tahun)   Kategori KETERANGAN SERTIFIKAT  \
# 0         128           NaN        NaN                    63
# 1   B 0 07 16          14.0     BAGASI                   NaN
# 2   B 0 07 17          14.0     BAGASI                   NaN
# 3  K1 0 09 01          12.0  EKSEKUTIF   2022-02-26 00:00:00
# 4  K1 0 09 02          12.0  EKSEKUTIF                   NaN
#
#   KETERANGAN RAMPCHECK
# 0                   68
# 1    Telah Dirampcheck
# 2                  NaN
# 3                  NaN
# 4    Telah Dirampcheck

# %% [markdown]
# menghapus data/kolom tertentu

# %%
data3 = data2.drop(columns=['KETERANGAN SERTIFIKAT', 'KETERANGAN RAMPCHECK'])

# %%
data3.head()
# Out:
#         Nomor  Usia (Tahun)   Kategori
# 0         128           NaN        NaN
# 1   B 0 07 16          14.0     BAGASI
# 2   B 0 07 17          14.0     BAGASI
# 3  K1 0 09 01          12.0  EKSEKUTIF
# 4  K1 0 09 02          12.0  EKSEKUTIF

# %% [markdown]
# menghapus data/baris tertentu

# %%
data4 = data2.drop(index=0)
data4.head()
# Out:
#         Nomor  Usia (Tahun)   Kategori KETERANGAN SERTIFIKAT  \
# 1   B 0 07 16          14.0     BAGASI                   NaN
# 2   B 0 07 17          14.0     BAGASI                   NaN
# 3  K1 0 09 01          12.0  EKSEKUTIF   2022-02-26 00:00:00
# 4  K1 0 09 02          12.0  EKSEKUTIF                   NaN
# 5  K1 0 16 28           5.0  EKSEKUTIF                   NaN
#
#   KETERANGAN RAMPCHECK
# 1    Telah Dirampcheck
# 2                  NaN
# 3                  NaN
# 4    Telah Dirampcheck
# 5                  NaN

# %%
data5 = data2.drop([3,4])
data5.head()
# Out:
#         Nomor  Usia (Tahun)   Kategori KETERANGAN SERTIFIKAT  \
# 0         128           NaN        NaN                    63
# 1   B 0 07 16          14.0     BAGASI                   NaN
# 2   B 0 07 17          14.0     BAGASI                   NaN
# 5  K1 0 16 28           5.0  EKSEKUTIF                   NaN
# 6  K1 0 16 29           5.0  EKSEKUTIF                   NaN
#
#   KETERANGAN RAMPCHECK
# 0                   68
# 1    Telah Dirampcheck
# 2                  NaN
# 5                  NaN
# 6                  NaN

# %% [markdown]
# mengganti nama kolom

# %%
data4 = data4.rename(columns={"Usia (Tahun)": "Umur", "KETERANGAN SERTIFIKAT" : "MasaBerlaku_Sertifikat" })
data4.dtypes
# Out:
# Nomor                      object
# Umur                      float64
# Kategori                   object
# MasaBerlaku_Sertifikat     object
# KETERANGAN RAMPCHECK       object
# dtype: object

# %% [markdown]
# menambah kolom baru diisi dengan data tertentu dengan fungsi lambda

# %%
data4['Ket'] = data4['Umur'].apply(lambda x: 'Muda' if x < 20 else 'Tua' )

# %%
data4.head()
# Out:
#         Nomor  Umur   Kategori MasaBerlaku_Sertifikat KETERANGAN RAMPCHECK  \
# 1   B 0 07 16  14.0     BAGASI                    NaN    Telah Dirampcheck
# 2   B 0 07 17  14.0     BAGASI                    NaN                  NaN
# 3  K1 0 09 01  12.0  EKSEKUTIF    2022-02-26 00:00:00                  NaN
# 4  K1 0 09 02  12.0  EKSEKUTIF                    NaN    Telah Dirampcheck
# 5  K1 0 16 28   5.0  EKSEKUTIF                    NaN                  NaN
#
#     Ket
# 1  Muda
# 2  Muda
# 3  Muda
# 4  Muda
# 5  Muda

# %% [markdown]
# memfilter data dengan kondisi tertentu

# %%
df =  data4.loc[(data4["Umur"] > 20)]
df.head()
# Out:
#          Nomor  Umur   Kategori MasaBerlaku_Sertifikat KETERANGAN RAMPCHECK  \
# 14  K1 0 80 04  41.0  EKSEKUTIF                    NaN    Telah Dirampcheck
# 15  K1 0 86 03  35.0  EKSEKUTIF    2022-02-26 00:00:00    Telah Dirampcheck
# 16  K1 0 86 04  35.0  EKSEKUTIF                    NaN                  NaN
# 17  K1 0 96 06  25.0  EKSEKUTIF                    NaN    Telah Dirampcheck
# 18  K1 0 98 12  22.0  EKSEKUTIF    2022-02-26 00:00:00                  NaN
#
#     Ket
# 14  Tua
# 15  Tua
# 16  Tua
# 17  Tua
# 18  Tua

# %%
df2 = data4[(data4['Kategori'] == 'EKSEKUTIF') & (data4['Ket'] == 'Muda') & (data4['KETERANGAN RAMPCHECK'] == 'Telah Dirampcheck')]
df2
# Out:
#            Nomor  Umur   Kategori MasaBerlaku_Sertifikat KETERANGAN RAMPCHECK  \
# 4     K1 0 09 02  12.0  EKSEKUTIF                    NaN    Telah Dirampcheck
# 13    K1 0 17 15   4.0  EKSEKUTIF                    NaN    Telah Dirampcheck
# 79    K1 0 18 50   3.0  EKSEKUTIF                    NaN    Telah Dirampcheck
# 80    K1 0 18 51   3.0  EKSEKUTIF                    NaN    Telah Dirampcheck
# 81    K1 0 18 52   3.0  EKSEKUTIF                    NaN    Telah Dirampcheck
# 82    K1 0 18 53   3.0  EKSEKUTIF                    NaN    Telah Dirampcheck
# 84    K1 0 18 55   3.0  EKSEKUTIF                    NaN    Telah Dirampcheck
# 85    K1 0 18 56   3.0  EKSEKUTIF                    NaN    Telah Dirampcheck
# 87    K1 0 18 58   3.0  EKSEKUTIF                    NaN    Telah Dirampcheck
# 97   K1 0 18 105   3.0  EKSEKUTIF    2022-02-26 00:00:00    Telah Dirampcheck
# 98   K1 0 18 106   3.0  EKSEKUTIF    2022-02-26 00:00:00    Telah Dirampcheck
# ...

# %%
df2.dtypes
# Out:
# Nomor                      object
# Umur                      float64
# Kategori                   object
# MasaBerlaku_Sertifikat     object
# KETERANGAN RAMPCHECK       object
# Ket                        object
# dtype: object

# %%
df2['MasaBerlaku_Sertifikat'] = pd.to_datetime(df2['MasaBerlaku_Sertifikat'])
df2.dtypes
# Out:
# <ipython-input-15-1be1e10e86fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['MasaBerlaku_Sertifikat'] = pd.to_datetime(df2['MasaBerlaku_Sertifikat'])
# Nomor                             object
# Umur                             float64
# Kategori                          object
# MasaBerlaku_Sertifikat    datetime64[ns]
# KETERANGAN RAMPCHECK              object
# Ket                               object
# dtype: object

# %%
df2
# Out:
#            Nomor  Umur   Kategori MasaBerlaku_Sertifikat KETERANGAN RAMPCHECK  \
# 4     K1 0 09 02  12.0  EKSEKUTIF                    NaT    Telah Dirampcheck
# 13    K1 0 17 15   4.0  EKSEKUTIF                    NaT    Telah Dirampcheck
# 79    K1 0 18 50   3.0  EKSEKUTIF                    NaT    Telah Dirampcheck
# 80    K1 0 18 51   3.0  EKSEKUTIF                    NaT    Telah Dirampcheck
# 81    K1 0 18 52   3.0  EKSEKUTIF                    NaT    Telah Dirampcheck
# 82    K1 0 18 53   3.0  EKSEKUTIF                    NaT    Telah Dirampcheck
# 84    K1 0 18 55   3.0  EKSEKUTIF                    NaT    Telah Dirampcheck
# 85    K1 0 18 56   3.0  EKSEKUTIF                    NaT    Telah Dirampcheck
# 87    K1 0 18 58   3.0  EKSEKUTIF                    NaT    Telah Dirampcheck
# 97   K1 0 18 105   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 98   K1 0 18 106   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# ...

# %%
 df2['MasaBerlaku_Sertifikat'] = df2['MasaBerlaku_Sertifikat'].fillna("2022-02-26")
# Out:
# <ipython-input-17-e92bd4bfae44>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['MasaBerlaku_Sertifikat'] = df2['MasaBerlaku_Sertifikat'].fillna("2022-02-26")

# %%
df2
# Out:
#            Nomor  Umur   Kategori MasaBerlaku_Sertifikat KETERANGAN RAMPCHECK  \
# 4     K1 0 09 02  12.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 13    K1 0 17 15   4.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 79    K1 0 18 50   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 80    K1 0 18 51   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 81    K1 0 18 52   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 82    K1 0 18 53   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 84    K1 0 18 55   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 85    K1 0 18 56   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 87    K1 0 18 58   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 97   K1 0 18 105   3.0  EKSEKUTIF    2022-02-26 00:00:00    Telah Dirampcheck
# 98   K1 0 18 106   3.0  EKSEKUTIF    2022-02-26 00:00:00    Telah Dirampcheck
# ...

# %%
df2.dtypes
# Out:
# Nomor                      object
# Umur                      float64
# Kategori                   object
# MasaBerlaku_Sertifikat     object
# KETERANGAN RAMPCHECK       object
# Ket                        object
# dtype: object

# %%
 df2['MasaBerlaku_Sertifikat'] =  df2['MasaBerlaku_Sertifikat'].astype("datetime64")
# Out:
# <ipython-input-20-37f4bb4dedbc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['MasaBerlaku_Sertifikat'] =  df2['MasaBerlaku_Sertifikat'].astype("datetime64")

# %%
df2.dtypes
# Out:
# Nomor                             object
# Umur                             float64
# Kategori                          object
# MasaBerlaku_Sertifikat    datetime64[ns]
# KETERANGAN RAMPCHECK              object
# Ket                               object
# dtype: object

# %%
df2
# Out:
#            Nomor  Umur   Kategori MasaBerlaku_Sertifikat KETERANGAN RAMPCHECK  \
# 4     K1 0 09 02  12.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 13    K1 0 17 15   4.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 79    K1 0 18 50   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 80    K1 0 18 51   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 81    K1 0 18 52   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 82    K1 0 18 53   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 84    K1 0 18 55   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 85    K1 0 18 56   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 87    K1 0 18 58   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 97   K1 0 18 105   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# 98   K1 0 18 106   3.0  EKSEKUTIF             2022-02-26    Telah Dirampcheck
# ...

# %%
df2.dtypes
# Out:
# Nomor                             object
# Umur                             float64
# Kategori                          object
# MasaBerlaku_Sertifikat    datetime64[ns]
# KETERANGAN RAMPCHECK              object
# Ket                               object
# dtype: object
